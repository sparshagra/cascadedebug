# %% [markdown]
# # CascadeDebug — GRPO Training (Phase 7)
#
# **Runtime:** T4 GPU (free tier)
# **Model:** Qwen2.5-3B-Instruct (4bit)
# **Algorithm:** GRPO (Group Relative Policy Optimization)
# **Estimated time:** 2-4 hours
#
# ### Instructions
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Run all cells in order
# 3. Results auto-push to GitHub and HF Space

# %%
# Cell 1: Install dependencies
# !pip install unsloth -q
# !pip install trl>=0.12.0 datasets matplotlib numpy huggingface_hub -q
print('✅ Dependencies installed!')

# %%
# Cell 2: Set HF token (required for pushing results)
import os
os.environ['HF_TOKEN'] = 'PASTE_YOUR_HF_TOKEN_HERE'  # Replace with your actual token
print('✅ HF token set')

# %%
# Cell 3: Clone repo and run training
# !git clone https://github.com/sparshagra/cascadedebug.git /content/cascadedebug 2>/dev/null || (cd /content/cascadedebug && git pull)
# %cd /content/cascadedebug

# Run the full training script
# %run training/train_grpo_colab.py
